# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dfPairedFull.csv")

# %%
df.head(100)
# Out:
#     xInit  yInit colorInit  xPheno  yPheno colorPheno    Dipole  Elongation  \
# 0    2400    600         m    1465     631          m  4.183770       276.0
# 1    3000    600         m    1819     607          m  3.083914       260.0
# 2    3600    600         m    2130     612          m  5.660618       292.0
# 3    4200    600         m    2444     617          m  4.689636       247.0
# 4    4800    600         m    2774     592          m  4.927941       277.0
# ..    ...    ...       ...     ...     ...        ...       ...         ...
# 95   6000   3150         g    3403    1969          g  0.041396        16.0
# 96   6600   3150         g    3742    1938          g  0.013998         7.0
# 97   7200   3150         g    4018    1915          g  0.032885        48.0
# 98   7800   3150         g    4379    1934          g  0.002844        48.0
# 99   8400   3150         g    4621    1904          g  0.181446        37.0
#
# ...

# %%
x, y = df.xInit.values, df.yInit.values

# %%
x, y = x//50, y//50

# %%
plt.scatter(x,y)
plt.gca().invert_yaxis()
