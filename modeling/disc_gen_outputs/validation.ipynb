# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np

# %%
hi = pickle.load(open("log3_11_03_1256.txt", "rb"))

scores3 = [item[0] for item in hi]

plt.plot(scores3)

# %%
hi = pickle.load(open("log4_11_03_1257.txt", "rb"))

scores4 = [item[0] for item in hi]

plt.plot(scores4)

# %%
scores3[-1], scores4[-1]
# Out:
# (0.39745675602196906, 0.41394848076082313)
